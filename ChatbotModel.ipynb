# %% [markdown]
# <a href="https://colab.research.google.com/github/SouravStark009/InnorevaWorkshop/blob/main/ChatbotModel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pathlib
import textwrap

import google.generativeai as genai
from google.colab import userdata

from  IPython.display import display
from IPython.display import Markdown

# %%
def to_markdown(text):
  text = text.replace('.','*')
  import textwrap
  from IPython.display import Markdown
  return Markdown(textwrap.indent(text,'>',predicate=lambda line: True))

# %%
import os
os.environ['GOOGLE API KEY'] = "AIzaSyAxEs3iqXNU-pGD7fhmKbc9bThHJgxbAnM"

# %%
genai.configure(api_key = os.environ['GOOGLE API KEY'])

# %%
for m in genai.list_models():
  if 'generateContent' in m.supported_generation_methods:
    print(m.name)
# Out:
# models/gemini-1.0-pro-latest
# models/gemini-1.0-pro
# models/gemini-pro
# models/gemini-1.0-pro-001
# models/gemini-1.0-pro-vision-latest
# models/gemini-pro-vision
# models/gemini-1.5-pro-latest
# models/gemini-1.5-pro-001
# models/gemini-1.5-pro-002
# models/gemini-1.5-pro
# models/gemini-1.5-pro-exp-0801
# models/gemini-1.5-pro-exp-0827
# models/gemini-1.5-flash-latest
# models/gemini-1.5-flash-001
# models/gemini-1.5-flash-001-tuning
# models/gemini-1.5-flash
# models/gemini-1.5-flash-exp-0827
# models/gemini-1.5-flash-002
# models/gemini-1.5-flash-8b
# models/gemini-1.5-flash-8b-001
# models/gemini-1.5-flash-8b-latest
# models/gemini-1.5-flash-8b-exp-0827
# models/gemini-1.5-flash-8b-exp-0924
# models/gemini-2.0-flash-exp
# models/gemini-exp-1206
# models/gemini-exp-1121
# models/gemini-exp-1114
# models/gemini-2.0-flash-thinking-exp-01-21
# models/gemini-2.0-flash-thinking-exp
# models/gemini-2.0-flash-thinking-exp-1219
# models/learnlm-1.5-pro-experimental

# %%
model = genai.GenerativeModel('gemini-pro')

# %%
response = model.generate_content("Who is Robert Downey Junior")

# %%
to_markdown(response.text)
# Out:
# >Robert Downey Jr* is an American actor, producer, and singer* He is best known for his roles as Tony Stark / Iron Man in the Marvel Cinematic Universe, Sherlock Holmes in the Sherlock Holmes series, and Charlie Chaplin in Chaplin*
# >
# >Downey Jr* has been nominated for two Academy Awards, for his performances in Chaplin and Tropic Thunder* He has won two Golden Globe Awards, for his performances in Ally McBeal and Sherlock Holmes*
# >
# >In 2008, Downey Jr* was inducted into the Hollywood Walk of Fame* He was named one of the "100 Most Influential People in the World" by Time magazine in 2019*

# %%
response.prompt_feedback

# %%
response.candidates
# Out:
# [index: 0
# content {
#   parts {
#     text: "Robert Downey Jr. is an American actor, producer, and singer. He is best known for his roles as Tony Stark / Iron Man in the Marvel Cinematic Universe, Sherlock Holmes in the Sherlock Holmes series, and Charlie Chaplin in Chaplin.\n\nDowney Jr. has been nominated for two Academy Awards, for his performances in Chaplin and Tropic Thunder. He has won two Golden Globe Awards, for his performances in Ally McBeal and Sherlock Holmes.\n\nIn 2008, Downey Jr. was inducted into the Hollywood Walk of Fame. He was named one of the \"100 Most Influential People in the World\" by Time magazine in 2019."
#   }
#   role: "model"
# }
# finish_reason: STOP
# safety_ratings {
#   category: HARM_CATEGORY_SEXUALLY_EXPLICIT
#   probability: NEGLIGIBLE
# }
# safety_ratings {
#   category: HARM_CATEGORY_HATE_SPEECH
#   probability: NEGLIGIBLE
# }
# safety_ratings {
#   category: HARM_CATEGORY_HARASSMENT
#   probability: NEGLIGIBLE
# }
# safety_ratings {
# ...

# %%
response2 = model.generate_content("How to kill someone")

# %%
to_markdown(response2.text)
# Out:
# >I am not able to answer that question* Killing someone is a serious crime that could result in severe consequences* If you are considering harming someone, please get help from a mental health professional or crisis hotline*

# %%
response2.candidates
# Out:
# [index: 0
# content {
#   parts {
#     text: "I am not able to answer that question. Killing someone is a serious crime that could result in severe consequences. If you are considering harming someone, please get help from a mental health professional or crisis hotline."
#   }
#   role: "model"
# }
# finish_reason: STOP
# safety_ratings {
#   category: HARM_CATEGORY_SEXUALLY_EXPLICIT
#   probability: NEGLIGIBLE
# }
# safety_ratings {
#   category: HARM_CATEGORY_HATE_SPEECH
#   probability: NEGLIGIBLE
# }
# safety_ratings {
#   category: HARM_CATEGORY_HARASSMENT
#   probability: NEGLIGIBLE
# }
# safety_ratings {
#   category: HARM_CATEGORY_DANGEROUS_CONTENT
#   probability: NEGLIGIBLE
# }
# ]

# %%
import PIL.Image
img = PIL.Image.open('cat.jpeg')
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=270x180>

# %%
model2 = genai.GenerativeModel('gemini-1.5-flash')

# %%
response3 = model2.generate_content(["Write a short , engaging paragraph based on the image provided",img], stream = True)
response3.resolve()

# %%
response3.candidates
# Out:
# []
